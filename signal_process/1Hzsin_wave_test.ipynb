# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fs = 8
t = np.arange(0, 1, 1/8)
x = np.sin(2*np.pi*t)
plt.plot(t, x, 'b.-')
plt.show()

# %%
xk = np.fft.fft(x)
absx = np.abs(xk)
px = 
N = len(xk)
fk = np.arange(0, fs, fs/N)
plt.bar(fk[:N//2+1], absx[:N//2+1]/N*2, width=0.5)
plt.xlabel("Hz")
plt.ylabel("Amplitude")
plt.title("spectrum")
plt.show()
