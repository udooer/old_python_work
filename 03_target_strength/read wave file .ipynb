# %%
path = r"G:\target_strength\2020_05_22_TS\*.wav"
# filename = r"\S4A02746_20000104_124448.wav"
# file = path + filename
from glob import glob

# %%
filelist = glob(path)

# %%
# from scipy.io import wavfile (do not support 24bits depth)
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
class SL():
    def __init__(self, file):
        self.file = file
        self.bits = 24
        self.range = 2
    def readWavFileToList(self):
#         fp = open(self.file, 'r')
#         self.fs, self.values = wavfile.read(self.file)
#         self.values = self.values*(self.range/pow(2,self.bits))
        self.values, self.fs = sf.read(self.file)
        self.length = len(self.values)
        print("total lenght: {}, time duration: {}".
              format(self.length, self.length//self.fs))
    def plot(self):
        time = np.arange(self.length)/self.fs
        plt.plot(time, self.values)
        title = self.file.split('\\')[-1].split('.')[0].split('_')
        self.plot_title = title[1] + "_" + title[2]
        self.freq = title[2]
        plt.title(self.plot_title)

# %%
b = SL(filelist[0])
b.readWavFileToList()
b.plot()
# Out:
# total lenght: 11950000, time duration: 116
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np

# %%
a = np.array([[4,7],[2,4]])
b = np.linalg.inv(a)
b
# Out:
# array([[ 2. , -3.5],
#        [-1. ,  2. ]])

# %%
# define a function that input the array of wavfile and set the threshold output the peak of index
def findPeak(x):
    last_value = x[0]
    for index, value in enumerate(x[1:]):

# %%
(b.values[:-2]-b.values[1:-1])>0
# Out:
# array([False, False,  True, ...,  True, False, False])

# %%
mask = ((b.values[1:-1]-b.values[2:])>0)*((b.values[:-2]-b.values[1:-1])>0)*(b.values[1:-1]>0.1)

# %%
indexs = []
for index, i in enumerate(mask):
    if(i):
        indexs.append(index+1)

# %%
indexs
# Out:
# [5806,
#  5817,
#  5827,
#  5838,
#  5848,
#  5858,
#  5868,
#  5889,
#  5899,
#  517904,
#  517916,
#  517926,
#  517936,
#  517946,
#  517967,
#  517977,
#  517987,
#  1030003,
#  1030014,
#  1030024,
#  1030035,
#  1030045,
#  1030055,
#  1030065,
#  1030086,
#  1030096,
#  1542101,
#  1542123,
#  1542133,
#  1542143,
#  1542153,
#  1542164,
#  1542174,
#  1542184,
#  1542194,
#  2054200,
#  2054211,
#  2054221,
#  2054242,
#  2054252,
#  2054262,
#  2054272,
#  2054283,
#  2054293,
#  2566298,
#  2566330,
#  2566340,
#  2566350,
#  2566371,
#  2566381,
#  2566391,
#  3078397,
#  3078408,
#  3078418,
#  3078449,
#  3078459,
#  3078469,
#  3078490,
#  3590495,
#  3590506,
#  3590527,
#  3590537,
#  3590547,
#  3590568,
#  3590578,
#  3590588,
#  4102594,
#  4102605,
#  4102615,
#  4102646,
#  4102656,
#  4102666,
#  4102687,
#  4614692,
#  4614703,
#  4614724,
#  4614734,
#  4614744,
#  4614765,
#  4614775,
#  4614785,
#  5126790,
#  5126791,
#  5126802,
#  5126812,
#  5126822,
#  5126853,
#  5126863,
#  5126873,
#  5126884,
#  5638889,
#  5638900,
#  5638921,
#  5638931,
#  5638941,
#  5638951,
#  5638972,
#  5638982,
#  6150987,
#  6150999,
#  6151009,
#  6151019,
#  6151029,
#  6151050,
#  6151060,
#  6151070,
#  6151081,
#  6663086,
#  6663097,
#  6663107,
#  6663118,
#  6663128,
#  6663138,
#  6663148,
#  6663169,
#  6663179,
#  7175184,
#  7175206,
#  7175216,
#  7175226,
#  7175247,
#  7175257,
#  7175267,
#  7687283,
#  7687294,
#  7687304,
#  7687325,
#  7687335,
#  7687345,
#  7687366,
#  7687376,
#  8199381,
#  8199403,
#  8199413,
#  8199423,
#  8199433,
#  8199444,
#  8199454,
#  8199464,
#  8711480,
#  8711491,
#  8711501,
#  8711522,
#  8711532,
#  8711542,
#  8711552,
#  8711563,
#  8711573,
#  9223578,
#  9223610,
#  9223620,
#  9223630,
#  9223651,
#  9223661,
#  9223671,
#  9735677,
#  9735688,
#  9735698,
#  9735729,
#  9735739,
#  9735749,
#  9735770,
#  10247775,
#  10247786,
#  10247807,
#  10247817,
#  10247827,
#  10247848,
#  10247858,
#  10247868,
#  10759873,
#  10759874,
#  10759885,
#  10759895,
#  10759926,
#  10759936,
#  10759946,
#  10759967,
#  11271972,
#  11271983,
#  11272004,
#  11272014,
#  11272024,
#  11272034,
#  11272055,
#  11272065,
#  11784070,
#  11784071,
#  11784082,
#  11784092,
#  11784102,
#  11784133,
#  11784143,
#  11784153,
#  11784164]
