# %%
# %matplotlib notebook
import librosa
import librosa.display as display
import matplotlib.pyplot as plt

# %%
x, sr = librosa.load('audio/simpleLoop.wav')

# %%
t = np.arange(0, len(x)*1/sr, 1/sr)
plt.figure(figsize=(6.4*1.5, 4.8))
plt.plot(t, x)
plt.plot(tenergy, energy/max(energy), 'r--', label="Energy")
plt.plot(tenergy, rmse, 'g-', label="rms")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="959.7500000000001">

# %%
import numpy as np
frame_length = 512
hop_length = 256
energy = np.array([sum(abs(x[i:i+frame_length])**2) for i in range(0, len(x), hop_length)])
rmse = np.sqrt(energy/frame_length)

# %%
tenergy = np.arange(0, len(x)*1/sr, 1/sr*hop_length)
