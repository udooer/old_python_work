# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
fs = 100000
f = 5000
time = np.arange(0, fs*0.4)/fs
signal = np.sin(2*np.pi*f*time)
fig, ax = plt.subplots()
ax.plot(time, signal)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import soundfile as sf

# %%
path = r"C:\Users\dindong\Downloads\white.wav"
values, fs = sf.read(path)

# %%
fs
# Out:
# 44100

# %%
from scipy.fftpack import fft

# %%
xk = fft(values)

# %%
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib notebook
f_wav, Pxx_den_wav = signal.periodogram(values, fs)
# plt.semilogy(f, Pxx_den)
# plt.ylim([1e-10, 1e2])
# plt.xlabel('frequency [Hz]')
# plt.ylabel('PSD [V**2/Hz]')
# plt.show()

# %%
path = r"C:\Users\dindong\Downloads\file\b.wav"
values, fs = sf.read(path)

# %%
fs
# Out:
# 44100

# %%
len(values)/fs
# Out:
# 21.58800453514739

# %%
values = values[:,0]

# %%
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib notebook
f_queen, Pxx_den_queen = signal.periodogram(values[fs*1:fs*5], fs)
# plt.semilogy(f, Pxx_den)
# plt.ylim([1e-10, 1e2])
# plt.xlabel('frequency [Hz]')
# plt.ylabel('PSD [V**2/Hz]')
# plt.show()

# %%
path = r"C:\Users\dindong\Downloads\c.wav"
values, fs = sf.read(path)

# %%
values = values[:,0]
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib notebook
f, Pxx_den_note = signal.periodogram(values[fs*2:fs*4], fs)
# plt.semilogy(f, Pxx_den)
# plt.ylim([1e-10, 1e-1])
# plt.xlabel('frequency [Hz]')
# plt.ylabel('PSD [V**2/Hz]')
# plt.show()

# %%
plt.semilogy(f, Pxx_den_queen/Pxx_den_wav)
plt.ylim([1e-10, 1e-1])
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-92fb02b2b49f> in <module>
# ----> 1 plt.semilogy(f, Pxx_den_queen/Pxx_den_wav)
#       2 plt.ylim([1e-10, 1e-1])
#       3 plt.xlabel('frequency [Hz]')
#       4 plt.ylabel('PSD [V**2/Hz]')
#       5 plt.show()
#
# ValueError: operands could not be broadcast together with shapes (88201,) (220501,)

# %%
len(f_queen)
# Out:
# 88201

# %%
len(f_wav)
# Out:
# 220501
